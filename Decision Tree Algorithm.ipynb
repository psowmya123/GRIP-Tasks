# %%
#Decision Tree Fitting
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
from sklearn.tree import export_text
clf = DecisionTreeClassifier(random_state=0,max_depth=2)
iris = load_iris()
#cross_val_score(clf, iris.data, iris.target, cv=10)
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.5, random_state=0)
#print("print training set\n",X_train)
#print("print testing set\n",X_test)
clf.fit(X_train,y_train)
clf.predict(X_test)
print("Avg. Accuracy",clf.score(X_train,y_train))
clf.predict_log_proba(X_test)
clf.predict_proba(X_test)
clf.cost_complexity_pruning_path(X_train,y_train)
clf.fit(X_train,y_train)
#print(clf.decision_path(X_train))
#clf.get_depth()
#clf.get_n_leaves()
plot_tree(clf)
r = export_text(clf, feature_names=iris['feature_names'])
print(r)
# Out:
# Avg. Accuracy 0.9733333333333334
# |--- petal width (cm) <= 0.75
# |   |--- class: 0
# |--- petal width (cm) >  0.75
# |   |--- petal length (cm) <= 5.05
# |   |   |--- class: 1
# |   |--- petal length (cm) >  5.05
# |   |   |--- class: 2
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py:1014: RuntimeWarning: divide by zero encountered in log
#   return np.log(proba)
